# %% [markdown]
#                  THIS PAGE CREATED TO SHOW THE ERROR NOTES [For My Reference]

# %%
# visualize the number of male and female customers using a horizontal bar chart with pastel colors, avoiding future warnings
plt.figure(figsize=(15, 5))
sbs.countplot(y="Gender", data=df, palette="pastel") ## Causing future Warning
sbn.countplot(y='Gender', data=df, hue='Gender', palette='pastel', legend=False) # Remove future warning by using hue and legend
plt.show()

C:\Users\anand\AppData\Local\Temp\ipykernel_8712\933786823.py:4:
FutureWarning: Passing palette without assigning hue is deprecated and will be removed in v0.14.0. 
Assign the y variable to hue and set legend=False for the same effect. sbn.countplot(y='Gender', data=df, palette='pastel')

# %%
plt.figure(figsize=(15,5))
# create a figure with width 15 inches and height 5 inches

# sbn.countplot(y='Gender', data=df, palette='pastel')
# original version commented out; caused FutureWarning in newer Seaborn versions

sbn.countplot(y='Gender', data=df, hue='Gender', palette='pastel', legend=False)
# plot a horizontal bar chart showing counts of each gender
# 'hue' assigns colors by gender to avoid FutureWarning
# 'palette="pastel"' sets pastel colors for the bars
# 'legend=False' hides the redundant legend

plt.show()
# display the plot

# %%
sns.barplot(data=age_counts, x="AgeGroup", y="Count", hue="AgeGroup", palette="mako", legend=False)

# %%
# Create DataFrame for Seaborn
income_counts = pd.DataFrame({
    "IncomeRange": ["0-30", "31-60", "61-90", "91-120", "121-150"],
    "Count": [len(ai_0_30), len(ai_31_60), len(ai_61_90), len(ai_91_120), len(ai_121_150)]
})

plt.figure(figsize=(15,6))  # set figure size
sns.barplot(data=income_counts, x="IncomeRange", y="Count", hue="IncomeRange", palette="Spectral",

# %%
from sklearn.cluster import KMeans
X1 = df[['Age', 'Spending Score (1-100)']].values
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X1)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12, 6))
plt.grid()
plt.plot(range(1, 11), wcss, linewidth=2, color="red", marker="8")
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method for Optimal Clusters')
plt.show()

# this will have future warning but display the output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.cluster import KMeans
# ----> 2 X1 = df[['Age', 'Spending Score (1-100)']].values
#       3 wcss = []
#       4 for i in range(1, 11):
#
# NameError: name 'df' is not defined

# %%
# apply K-Means clustering to group data points into 4 clusters
kmeans = KMeans(n_clusters=4)
label = kmeans.fit_predict(X1)
print(label)

# this will have future warning but display the output

# %%
from sklearn.cluster import KMeans

X2 = df[['Annual Income (k$)', 'Spending Score (1-100)']].values
wcss = []

for i in range(1, 11):
    kmeans = KMeans(
        n_clusters=i,
        init='k-means++',
        n_init=10,        # fixes future warning
        random_state=42
    )
    kmeans.fit(X2)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(12, 6))
plt.grid()
plt.plot(range(1, 11), wcss, linewidth=2, color="red", marker="8")
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method for Optimal Clusters')
plt.show()
