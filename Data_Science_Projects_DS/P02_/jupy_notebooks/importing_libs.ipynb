# %%
# importing the required Python libraries used for data processing, analysis, and visualization.
### Used from requirement.txt file ###

import numpy as np # for numerical operations
# %pip install numpy
import pandas as pd # for data handling and DataFrame
# %pip install pandas
import matplotlib.pyplot as plt  # for plotting charts
# %pip install matplotlib
import seaborn as sbn  # for statistical plots
# %pip install seaborn 
import sklearn.cluster as KMeans  # K-means clustering model

from sklearn.preprocessing import LabelEncoder
from mpl_toolkits.mplot3d import Axes3D
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.3 MB 5.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.3 MB 4.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.3 MB 4.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/11.3 MB 4.3 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.3 MB 4.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.3 MB 4.1 MB/s eta 0:00:02
#    -------------------- ------------------- 5.8/11.3 MB 4.0 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.3 MB 4.0 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.3 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.3 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.3 MB 4.0 MB/s eta 0:00:01
# ...

# %%
# %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 5.0 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.1 MB 4.4 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.1 MB 4.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 3.9 MB/s  0:00:02
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.6 MB 3.7 MB/s eta 0:00:01
# ...

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.9 MB 6.7 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/8.9 MB 4.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/8.9 MB 4.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.4/8.9 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 4.2/8.9 MB 3.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.0/8.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------- -------------- 5.8/8.9 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.6/8.9 MB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 7.3/8.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 8.1/8.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 3.9 MB/s  0:00:02
# ...
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
# ...
