# %% [markdown]
# # Customer Segmentation using Python
#
# I used Python and K-Means clustering to segment customers based on income and spending behavior, enabling data-driven marketing decisions.
#
# ### ⭐ Situation
#
# The business had customer data but no clear understanding of different customer types, making it hard to design targeted marketing strategies.
#
# ### 🎯 Task
#
# My task was to analyze customer behavior and segment customers into meaningful groups using data analytics and machine learning.
#
# ### 🛠 Action
#
# 1) Cleaned and explored the dataset using Pandas and NumPy
#
# 2) Performed EDA to understand spending and income patterns
#
# 3) Standardized features and applied K-Means clustering
#
# 4) Used the Elbow Method to identify the optimal number of clusters
#
# 5) Visualized clusters to interpret customer behavior clearly
#
# ### 📈 Result
#
# The model successfully grouped customers into distinct segments, helping identify:-
#
# --> High-value customers
#
# --> Moderate spenders
#
# --> Low-spending but potential growth customers
#
# ## Outcome:
# These insights can be directly used for targeted marketing, better customer retention, and revenue optimization.
